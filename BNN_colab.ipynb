# %%
# %run BNN.py
# Out:
# Epoch 1/10: 92.2800%
# Epoch 2/10: 93.6100%
# Epoch 3/10: 94.5300%
# Epoch 4/10: 93.6800%
# Epoch 5/10: 94.2100%
# Epoch 6/10: 94.4800%
# Epoch 7/10: 93.5800%
# Epoch 8/10: 95.6900%
# Epoch 9/10: 94.7200%
# Epoch 10/10: 95.0100%
